# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
tienda['lat']
# Out:
# 0        4.60971
# 1        6.25184
# 2       10.39972
# 3        3.43722
# 4        6.25184
#           ...
# 2354     6.25184
# 2355     4.60971
# 2356     3.43722
# 2357     1.21361
# 2358     3.43722
# Name: lat, Length: 2359, dtype: float64

# %% [markdown]
# # 1. Análisis de facturación

# %% [markdown]
# ## 1.1. Facturación por tienda:

# %%
#Algunos ajustes previos para la visualización de los datos
pd.set_option('expand_frame_repr', False)
pd.set_option('display.max_columns', None)

lista_tiendas = [tienda, tienda2, tienda3, tienda4]  # Crea una lista con los DataFrames de las tiendas
print("********** FACTURACION TOTAL POR TIENDA ********** \n")

#Función que calcula la facturación para cada una de las tiendas:
def imprimir_facturacion(tiendas):
  """Recibe una lista de DataFrames y calcula la facturación
  a partir de la columna Precio """
  contador = 1
  lista_aux = []
  for facturacion in tiendas:
    monto = sum(facturacion["Precio"])
    lista_aux.append(monto)
    print(f"Facturación total de la Tienda {contador}: {monto:,.2f}", "\n")
    contador += 1
  return lista_aux

facturación_por_tienda = imprimir_facturacion(lista_tiendas)
# Out:
# ********** FACTURACION TOTAL POR TIENDA **********
#
# Facturación total de la Tienda 1: 1,150,880,400.00
#
# Facturación total de la Tienda 2: 1,116,343,500.00
#
# Facturación total de la Tienda 3: 1,098,019,600.00
#
# Facturación total de la Tienda 4: 1,038,375,700.00

# %% [markdown]
# ## 1.2. Visualización de los resultados (facturación):

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
facturacion = facturación_por_tienda

#Dibuja un gráfico de barras
plt.bar(tiendas, facturacion, color = "royalblue")
plt.title("Facturación por tienda - Ene 2020 / Dic 2023")
plt.xlabel("Tiendas")
plt.ylabel("Monto")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ## 2.1.Monto de ventas por categoría para cada tienda:

# %%
nombre_tiendas = {"tiendas": ["TIENDA 1", "TIENDA 2", "TIENDA 3", "TIENDA 4"]}

lista_categorias = []   #almacena las categorías para comparación
# Crea una lista con las categorías
for categoria in tienda["Categoría del Producto"]:
  if categoria not in lista_categorias:
    lista_categorias.append(categoria)

# Función que suma los montos de la facturación por categoría
def monto_categoria(tienda):
  """Esta función recibe como parámetro un DataFrame de una tienda
  y calcula los montos de facturación por categoría de producto"""
  monto_categoria_tienda = []
  monto_total = 0
  for categoria in lista_categorias:
    for i, monto in enumerate(tienda['Precio']):
      if categoria == tienda['Categoría del Producto'][i]:
        monto_total += monto
    monto_categoria_tienda.append(monto_total)
    monto_total = 0
  return monto_categoria_tienda

#listas con los montos por categoría por tienda
monto_categoria_tienda_1 = monto_categoria(tienda)
monto_categoria_tienda_2 = monto_categoria(tienda2)
monto_categoria_tienda_3 = monto_categoria(tienda3)
monto_categoria_tienda_4 = monto_categoria(tienda4)


#lista de listas con los montos por categoria
listas_monto_categoria = [monto_categoria_tienda_1, monto_categoria_tienda_2, monto_categoria_tienda_3, monto_categoria_tienda_4]

#Crea un diccionario con la facturación (montos) por categoría para cada tienda (tabla)
lista_aux = []
tabla_montos_categoria = {}
for i, categoria in enumerate(lista_categorias):
  for montos in listas_monto_categoria:
    lista_aux.append(montos[i])
  tabla_montos_categoria[categoria] = lista_aux
  lista_aux = []

#Imprime la tabla en pantalla
print("------ TABLA: FACTURACION POR CATEGORIA -----\n")
tabla_montos_categoria = {**nombre_tiendas, **tabla_montos_categoria}
pd.DataFrame(tabla_montos_categoria)
# Out:
# ------ TABLA: FACTURACION POR CATEGORIA -----
#     tiendas  Electrónicos      Muebles    Juguetes  Electrodomésticos  Artículos para el hogar  Deportes y diversión      Libros  Instrumentos musicales
# 0  TIENDA 1   429493500.0  187633700.0  17995700.0        363685200.0               12698400.0            39290000.0   8784900.0              91299000.0
# 1  TIENDA 2   410831100.0  176426300.0  15945400.0        348567800.0               14746900.0            34744500.0  10091200.0             104990300.0
# 2  TIENDA 3   410775800.0  201072100.0  19401100.0        329237900.0               15060000.0            35593100.0   9498700.0              77380900.0
# 3  TIENDA 4   409476100.0  192528900.0  20262200.0        283260200.0               15074500.0            33350100.0   9321300.0              75102400.0

# %% [markdown]
# ## 2.2.Cantidad de productos vendidos por categoría

# %%
#Función que suma la cantidad de productos vendidos por categoría
def cantidad_productos(tienda):
  """Recibe como parámetro un DataFrame de una tienda y calcula la
  cantidad de productos vendidor por categoría"""
  contador = 0
  cantidad_productos_tienda = []
  for categoria in lista_categorias:
    for i, categoria_producto in enumerate(tienda['Categoría del Producto']):
      if categoria == categoria_producto:
        contador += 1
    cantidad_productos_tienda.append(contador)
    contador = 0
  return cantidad_productos_tienda

# istas que contienen la cantidad de ventas por categoría de producto por tienda
cantidad_productos_tienda_1 = cantidad_productos(tienda)
cantidad_productos_tienda_2 = cantidad_productos(tienda2)
cantidad_productos_tienda_3 = cantidad_productos(tienda3)
cantidad_productos_tienda_4 = cantidad_productos(tienda4)

#lista de listas con los productos vendidos por categoria por tienda
productos_por_tienda = [cantidad_productos_tienda_1, cantidad_productos_tienda_2, cantidad_productos_tienda_3, cantidad_productos_tienda_4]

#crea un diccionario de la cantidad de productos por categoría por tienda (tabla)
total_por_producto = [] #lista con la sumatoria de productos por categoría vendidos por todas las tiendas
lista_aux = []
tabla_cantidad_productos = {}   #lista de listas
for i, categoria in enumerate(lista_categorias):
  for cantidad_productos in productos_por_tienda:
    lista_aux.append(cantidad_productos[i])
  total_por_producto.append(sum(lista_aux))   #calcula total por producto y lo guarda
  tabla_cantidad_productos[categoria] = lista_aux   #guarda lista en la lista tabla_cantidad_productos
  lista_aux = []

#Imprime la tabla
print("------ TABLA: PRODUCTOS VENDIDOS POR CATEGORIA -----\n")
tabla_cantidad_productos = {**nombre_tiendas, **tabla_cantidad_productos}
pd.DataFrame(tabla_cantidad_productos)
# Out:
# ------ TABLA: PRODUCTOS VENDIDOS POR CATEGORIA -----
#     tiendas  Electrónicos  Muebles  Juguetes  Electrodomésticos  Artículos para el hogar  Deportes y diversión  Libros  Instrumentos musicales
# 0  TIENDA 1           448      465       324                312                      171                   284     173                     182
# 1  TIENDA 2           422      442       313                305                      181                   275     197                     224
# 2  TIENDA 3           451      499       315                278                      177                   277     185                     177
# 3  TIENDA 4           451      480       338                254                      201                   277     187                     170

# %% [markdown]
# ## 2.3. Visualización de los resultados, ventas por categoría:

# %%
#dibuja gráfica de barras horizontales por totales por categoría de productos
plt.barh(lista_categorias, total_por_producto, color = "orange")
plt.title("Ventas por categoría (todas las tiendas)")
plt.xlabel("Cantidad de productos")
plt.show()

# %%
#dibuja gráfica de barras por totales por categoría de productos (Ora opción de visualización)
color_barra = ['orange', 'orange', 'orange', 'blue', 'blue', 'blue', 'blue', 'blue']
plt.bar(lista_categorias, total_por_producto, color = color_barra)
plt.title("Ventas por categoría (todas las tiendas)")
plt.ylabel("Cantidad de productos")
plt.xticks(rotation = 90)
plt.show()

print("En color naranja las categorías más vendidas")
# Out:
# En color naranja las categorías más vendidas

# %%
# Crea un Pie chart para las ventas de productos por categoría para todas las tiendas
plt.pie(total_por_producto, labels = lista_categorias)
plt.title("Ventas por categoría")
plt.show()

# %%
nombre_tiendas = tabla_cantidad_productos["tiendas"]  #crea una lista con los nombres de las tiendas

# Crea un diccionario de la cantidad vendida de productos por categoría por tienda sin la clave "tiendas"
categorias_ventas = {clave: valores for (clave, valores) in tabla_cantidad_productos.items() if clave != "tiendas"}

x = np.arange(len(nombre_tiendas))   #ubicacion de las etiquetas
ancho_barra = 0.10  #ancho de las barras
multiplicador = 0

fig, ax = plt.subplots(figsize =(17, 7))

for categoria, cantidad in categorias_ventas.items():
  offset = ancho_barra * multiplicador
  contenedor = ax.bar(x + offset, cantidad, ancho_barra, label = categoria)
  ax.bar_label(contenedor, padding = 3)
  multiplicador += 1

# COnfiguración de la gráfica (texto, etiquetas, ticks del eje etc.)
ax.set_ylabel("Cantidad productos")
ax.set_title("Ventas según categoría por tienda")
ax.set_xticks(x + ancho_barra * 3.5, nombre_tiendas)
ax.legend(loc='upper left', ncols = 3)
ax.set_ylim(0, 600)
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Función que crea una lista con las calificaciones de las tiendas
def calcular_calificacion(lista):
  lista_aux = []
  for elemento in lista:
    promedio = sum(elemento["Calificación"]) / len(elemento["Calificación"])
    lista_aux.append(promedio)
  return lista_aux

# Muestra la lista generada de las calificaciones promedio
calificacion_promedio_tiendas = calcular_calificacion(lista_tiendas)
print("======== CALIFICACION PROMEDIO POR TIENDA ========")
pd.Series(calificacion_promedio_tiendas, index = tiendas)
# Out:
# ======== CALIFICACION PROMEDIO POR TIENDA ========
# Tienda 1    3.976685
# Tienda 2    4.037304
# Tienda 3    4.048326
# Tienda 4    3.995759
# dtype: float64

# %% [markdown]
# ## 3.1. Visualización de los datos para las calificaciones de las ventas

# %%
#preparación de los datos para armar una tabla y las gráficas
lista_auxiliar = []
calificacion_por_tiendas = []  #Lista de lista con los datos de las calificaciones para cada tienda
for x in range(1, 6):
  for tienda_aux in lista_tiendas:
    lista_auxiliar.append(list(tienda_aux['Calificación']).count(x))
  calificacion_por_tiendas.append(lista_auxiliar)
  lista_auxiliar = []

# %%
import matplotlib.ticker as ticker
# lista con eqtiquetas para la gráfica
etiquetas_puntaje = ["1 punto", "2 puntos", "3 puntos", "4 puntos", "5 puntos"]

# crea un diccionario con datos para la gráfica
datos_puntaje = {llaves : valores for (llaves, valores) in zip(etiquetas_puntaje, calificacion_por_tiendas)}

ancho_barras = 0.6  # ancho de las barras

fig, ax = plt.subplots(figsize = (7, 8))
bottom = np.zeros(4)

#crea las barras de la gráfica
for etiquetas, puntajes in datos_puntaje.items():
  contenedor = ax.bar(tiendas, puntajes, ancho_barras, label = etiquetas, bottom = bottom)
  bottom += puntajes
  ax.bar_label(contenedor, label_type = "center")

ax.set_title("Calificaciones dadas a las ventas")
ax.legend()
ax.set_ylim(0, 3000)
ax.yaxis.set_major_locator(ticker.NullLocator())
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# crea una lista con los valores únicos de la lista de productos
nombre_productos = tienda['Producto'].unique()
nombre_productos.sort()
dic_temp = {}
dic_temp["Producto"] = nombre_productos

# crea una lista de las cantidades de productos vendidos por tipo en cada tienda
cantidad_productos_vendidos = []
lista_auxiliar = []

for una_tienda in lista_tiendas:
  for producto_n in nombre_productos:
    lista_auxiliar.append(list(una_tienda["Producto"]).count(producto_n))
  cantidad_productos_vendidos.append(lista_auxiliar)
  lista_auxiliar = []

#crea un diccionario con 4 listas, una por tienda, con la cantidad de productos por tipo
tabla_cantidad_productos = {llaves:valores for (llaves, valores) in zip(tiendas, cantidad_productos_vendidos)}

#agrega la columna de nombres de los productos al diccionario
tabla_cantidad_productos = {**dic_temp, **tabla_cantidad_productos}

#crea un DataFrame a partir del diccionario de productos
tabla_productos = pd.DataFrame(tabla_cantidad_productos)

#muestra la tabla con las cantidades de TODOS los productos vendidos por tienda
tabla_productos
# Out:
#                        Producto  Tienda 1  Tienda 2  Tienda 3  Tienda 4
# 0             Ajedrez de madera        49        45        47        39
# 1                       Armario        60        54        49        34
# 2             Asistente virtual        40        38        39        50
# 3                   Auriculares        50        37        43        44
# 4     Auriculares con micrófono        33        44        39        42
# 5           Balón de baloncesto        55        42        50        50
# 6             Balón de voleibol        42        46        48        48
# 7                       Batería        53        61        41        48
# 8                     Bicicleta        54        45        52        45
# 9       Bloques de construcción        56        54        35        54
# 10                     Cama box        44        47        46        62
# 11                    Cama king        44        45        56        56
# 12    Carrito de control remoto        52        47        52        55
# 13                 Celular ABXY        33        41        44        39
# 14  Ciencia de datos con Python        39        43        46        38
# 15                   Cubertería        52        39        39        59
# 16              Cubo mágico 8x8        44        45        44        47
# 17           Cuerda para saltar        40        50        53        43
# 18      Dashboards con Power BI        42        43        40        56
# 19               Dinosaurio Rex        40        42        46        47
# 20                       Estufa        45        42        53        47
# 21            Guitarra acústica        46        58        47        37
# 22           Guitarra eléctrica        47        47        38        33
# 23                    Impresora        54        34        50        50
# 24    Iniciando en programación        41        65        46        43
# 25                    Iphone 15        49        55        46        48
# 26                Juego de mesa        43        32        52        48
# 27                Kit de bancas        44        45        57        42
# 28             Lavadora de ropa        47        49        42        38
# 29                 Lavavajillas        48        46        52        43
# 30               Mesa de centro        44        45        42        44
# 31              Mesa de comedor        40        34        56        55
# 32                Mesa de noche        56        44        55        55
# 33                   Microondas        60        62        36        48
# 34                      Mochila        39        45        36        43
# 35          Modelado predictivo        51        46        53        50
# 36                  Muñeca bebé        40        48        39        48
# 37              Olla de presión        35        44        47        46
# 38                    Pandereta        36        58        51        52
# 39                 Refrigerador        54        49        50        38
# 40             Secadora de ropa        58        57        45        40
# 41                 Set de ollas        43        52        55        50
# 42                 Set de vasos        41        46        36        46
# 43             Silla de oficina        46        49        46        40
# 44                       Sillón        41        35        47        45
# 45                     Smart TV        44        40        54        54
# 46                   Smartwatch        43        44        46        39
# 47              Sofá reclinable        46        44        45        47
# 48                TV LED UHD 4K        60        45        42        40
# 49                  Tablet ABXY        42        44        48        45
# 50                 Vaso térmico        54        47        38        48

# %% [markdown]
# ## 4.1. Visualización de los datos (productos más o menos vendidos por tienda)

# %%
#crea una tabla de los productos ordenada por la columna Tienda 1
tabla_productos_ordenada_tienda_1 = tabla_productos.sort_values(by = "Tienda 1")

#creas dos tablas: los 10 productos más vendidos y 10 menos vendidos, tienda 1
productos_mas_vendidos_t1 = tabla_productos_ordenada_tienda_1.tail(10)
productos_menos_vendidos_t1 = tabla_productos_ordenada_tienda_1.head(10)

#crea una tabla de los productos ordenada por la columna Tienda 2
tabla_productos_ordenada_tienda_2 = tabla_productos.sort_values(by = "Tienda 2")

#creas dos tablas: los 10 productos más vendidos y 10 menos vendidos, tienda 2
productos_mas_vendidos_t2 = tabla_productos_ordenada_tienda_2.tail(10)
productos_menos_vendidos_t2 = tabla_productos_ordenada_tienda_2.head(10)

#crea una tabla de los productos ordenada por la columna Tienda 3
tabla_productos_ordenada_tienda_3 = tabla_productos.sort_values(by = "Tienda 3")

#creas dos tablas: los 10 productos más vendidos y 10 menos vendidos, tienda 3
productos_mas_vendidos_t3 = tabla_productos_ordenada_tienda_3.tail(10)
productos_menos_vendidos_t3 = tabla_productos_ordenada_tienda_3.head(10)

#crea una tabla de los productos ordenada por la columna Tienda 4
tabla_productos_ordenada_tienda_4 = tabla_productos.sort_values(by = "Tienda 4")

#creas dos tablas: los 10 productos más vendidos y 10 menos vendidos, tienda 4
productos_mas_vendidos_t4 = tabla_productos_ordenada_tienda_4.tail(10)
productos_menos_vendidos_t4 = tabla_productos_ordenada_tienda_4.head(10)

# %%
#dibuja gráficas de los 10 productos más y menos vendidos en la tienda 1
plt.barh(productos_mas_vendidos_t1["Producto"], productos_mas_vendidos_t1["Tienda 1"], color = "c")
plt.title("Los productos más vendidos de la Tienda 1")
plt.xlabel("Cantidad de productos")
plt.show()

plt.barh(productos_menos_vendidos_t1["Producto"], productos_menos_vendidos_t1["Tienda 1"], color = "olive")
plt.title("Los productos menos vendidos de la Tienda 1")
plt.xlabel("Cantidad de productos")
plt.show()

# %%
#dibuja gráficas de los 10 productos más y menos vendidos en la tienda 2
plt.barh(productos_mas_vendidos_t2["Producto"], productos_mas_vendidos_t2["Tienda 2"], color = "r")
plt.title("Los productos más vendidos de la Tienda 2")
plt.xlabel("Cantidad de productos")
plt.show()

plt.barh(productos_menos_vendidos_t2["Producto"], productos_menos_vendidos_t2["Tienda 2"], color = "coral")
plt.title("Los productos menos vendidos de la Tienda 2")
plt.xlabel("Cantidad de productos")
plt.show()

# %%
#dibuja gráficas de los 10 productos más y menos vendidos en la tienda 3
plt.barh(productos_mas_vendidos_t3["Producto"], productos_mas_vendidos_t3["Tienda 3"], color = "gold")
plt.title("Los productos más vendidos de la Tienda 3")
plt.xlabel("Cantidad de productos")
plt.show()

plt.barh(productos_menos_vendidos_t3["Producto"], productos_menos_vendidos_t3["Tienda 3"], color = "y")
plt.title("Los productos menos vendidos de la Tienda 3")
plt.xlabel("Cantidad de productos")
plt.show()

# %%
#dibuja gráficas de los 10 productos más y menos vendidos en la tienda 4
plt.barh(productos_mas_vendidos_t4["Producto"], productos_mas_vendidos_t4["Tienda 4"], color = "blue")
plt.title("Los productos más vendidos de la Tienda 4")
plt.xlabel("Cantidad de productos")
plt.show()

plt.barh(productos_menos_vendidos_t4["Producto"], productos_menos_vendidos_t4["Tienda 4"], color = "slateblue")
plt.title("Los productos menos vendidos de la Tienda 4")
plt.xlabel("Cantidad de productos")
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
#Calcula el envío promedio para cada tienda
envio_promedio_por_tienda = []
for i, una_tienda in enumerate(lista_tiendas):
  promedio_envios = sum(una_tienda["Costo de envío"]) / len(una_tienda['Costo de envío'])
  print(f"Costo del envío promedio de la Tienda {i + 1}: {promedio_envios:.2f}", "\n")
  envio_promedio_por_tienda.append(promedio_envios)
# Out:
# Costo del envío promedio de la Tienda 1: 26018.61
#
# Costo del envío promedio de la Tienda 2: 25216.24
#
# Costo del envío promedio de la Tienda 3: 24805.68
#
# Costo del envío promedio de la Tienda 4: 23459.46

# %% [markdown]
# ## 5.1. Visualización del envío promedio por tienda

# %%
#Dibuja un gráfico de barras
plt.bar(tiendas, envio_promedio_por_tienda, color = "lightblue")
plt.title("Costo del envío promedio para cada tienda")
plt.xlabel("Tiendas")
plt.ylabel("Monto")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %% [markdown]
# # EXTRA: análisis del desempeño geográfico

# %%
# crea una lista con las ciudades donde se realizan las ventas
lugares_de_ventas = tienda['Lugar de Compra'].unique()

dic_temp = {}   #diccionario temporal con las ciudades
dic_temp["Lugar de venta"] = lugares_de_ventas

# crea una lista de las cantidades de productos vendidos por tipo en cada tienda
ventas_por_ciudad = []
lista_auxiliar = []

for una_tienda in lista_tiendas:
  for ciudades in lugares_de_ventas:
    lista_auxiliar.append(list(una_tienda["Lugar de Compra"]).count(ciudades))
  ventas_por_ciudad.append(lista_auxiliar)
  lista_auxiliar = []

#crea un diccionario con 4 listas, una por tienda, con los lugares de las ventas
tabla_lugares_ventas = {llaves:valores for (llaves, valores) in zip(tiendas, ventas_por_ciudad)}

#agrega la columna del nombre de las ciudades al diccionario
tabla_lugares_ventas = {**dic_temp, **tabla_lugares_ventas}

#crea un DataFrame a partir del diccionario de la ubicación de las ventas (compras)
tabla_lugares = pd.DataFrame(tabla_lugares_ventas)

#muestra la tabla
tabla_lugares.sort_values(by= "Tienda 1", ascending= False)
# Out:
#    Lugar de venta  Tienda 1  Tienda 2  Tienda 3  Tienda 4
# 0          Bogotá       984       985       983       991
# 1        Medellín       563       594       580       577
# 3            Cali       283       222       248       254
# 5         Pereira       133       128       134       122
# 6    Barranquilla        75        78        77        80
# 2       Cartagena        53        70        56        63
# 9          Cúcuta        51        59        44        32
# 15       Riohacha        40        35        44        44
# 4     Santa Marta        32        40        44        35
# 17        Leticia        32        34        41        35
# 12    Bucaramanga        31        50        50        50
# 14          Pasto        23        25        16        30
# 10      Manizales        15        13         7         6
# 16        Armenia        14         4         7         3
# 7   Villavicencio        11         6         5         7
# 11          Neiva         6         6        10        18
# 8         Inírida         5         2         4         3
# 18         Soacha         5         4         6         4
# 13     Valledupar         3         4         3         4

# %% [markdown]
# ## Extra: diagramas de dispersión
# Muestran las ventas (o compras) por ciudad para cada tienda

# %%
#Diagrama de dispersión para la Tienda, relaciona la cantidad de compras (ventas) con el lugar correspondiente
x = np.array(tabla_lugares['Tienda 1'])
y = np.array(tabla_lugares['Lugar de venta'])

plt.scatter(x, y, s= list(tabla_lugares['Tienda 1']), edgecolors="b", linewidth=1) #Un mayor tamaño de los círculos indica más ventas en dicho lugar
plt.title("Tienda 1 - Ventas por ciudad")
plt.xlabel("Cantidad de ventas")
plt.show()

# %%
#Diagrama de dispersión para la Tienda, relaciona la cantidad de compras (ventas) con el lugar correspondiente
x = np.array(tabla_lugares['Tienda 2'])
y = np.array(tabla_lugares['Lugar de venta'])

plt.scatter(x, y, s= list(tabla_lugares['Tienda 2']), edgecolors="b", linewidth=1) #Un mayor tamaño de los círculos indica más ventas en dicho lugar
plt.title("Tienda 2 - Ventas por ciudad")
plt.xlabel("Cantidad de ventas")
plt.show()

# %%
#Diagrama de dispersión para la Tienda, relaciona la cantidad de compras (ventas) con el lugar correspondiente
x = np.array(tabla_lugares['Tienda 3'])
y = np.array(tabla_lugares['Lugar de venta'])

plt.scatter(x, y, s= list(tabla_lugares['Tienda 3']), edgecolors="b", linewidth=1) #Un mayor tamaño de los círculos indica más ventas en dicho lugar
plt.title("Tienda 3 - Ventas por ciudad")
plt.xlabel("Cantidad de ventas")
plt.show()

# %%
#Diagrama de dispersión para la Tienda, relaciona la cantidad de compras (ventas) con el lugar correspondiente
x = np.array(tabla_lugares['Tienda 4'])
y = np.array(tabla_lugares['Lugar de venta'])

plt.scatter(x, y, s= list(tabla_lugares['Tienda 4']), edgecolors="b", linewidth=1) #Un mayor tamaño de los círculos indica más ventas en dicho lugar
plt.title("Tienda 4 - Ventas por ciudad")
plt.xlabel("Cantidad de ventas")
plt.show()

# %% [markdown]
# ## Mapa que muestra las ciudades donde se realizan las ventas (para todas las tiendas)

# %%
#Crea un mapa que muestra las ciudades donde se venden los productos de las tiendas:
import folium

coordenadas = [4.60971 , -74.08175]

mapa_tienda_1 = folium.Map(location= coordenadas, zoom_start= 6)

for i in range(len(tienda)):
   folium.Marker(location= [tienda['lat'][i], tienda['lon'][i]], popup= tienda['Lugar de Compra'][i]).add_to(mapa_tienda_1)

mapa_tienda_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8dd96b3fed37d6d62cb2ffdefd3e82b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8dd96b3fed37d6d62cb2ffdefd3e82b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8dd96b3fed37d6d62cb2ffdefd3e82b0 = L.map(
#                 &quot;map_8dd96b3fed37d6d62cb2ffdefd3e82b0&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca73d8f1f6ae7c5deb03b6688986380a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca73d8f1f6ae7c5deb03b6688986380a.addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#             var marker_1382786aeee83608d66a656efafb184a = L.marker(
#                 [4.60971, -74.08175],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#         var popup_fce9b0398a7fc985bf6c109ab793fba7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a3f6ecaed81cbfbb0e0db1655883e7c = $(`&lt;div id=&quot;html_6a3f6ecaed81cbfbb0e0db1655883e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_fce9b0398a7fc985bf6c109ab793fba7.setContent(html_6a3f6ecaed81cbfbb0e0db1655883e7c);
#
#
#
#         marker_1382786aeee83608d66a656efafb184a.bindPopup(popup_fce9b0398a7fc985bf6c109ab793fba7)
#         ;
#
#
#
#
#             var marker_f39d24aa8adb28cd19d02df6c0f359f8 = L.marker(
#                 [6.25184, -75.56359],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#         var popup_8490abfcf897bdb776fe061cbd48f50e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70ef85479da80107e73a45f295e85491 = $(`&lt;div id=&quot;html_70ef85479da80107e73a45f295e85491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_8490abfcf897bdb776fe061cbd48f50e.setContent(html_70ef85479da80107e73a45f295e85491);
#
#
#
#         marker_f39d24aa8adb28cd19d02df6c0f359f8.bindPopup(popup_8490abfcf897bdb776fe061cbd48f50e)
#         ;
#
#
#
#
#             var marker_e9b6bb56ece11d0c50bb9d67aa06eb78 = L.marker(
#                 [10.39972, -75.51444],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#         var popup_43e80410d1b2ae9528467db3f1ad7911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1422a315b1d86a8e9054d35c78f73219 = $(`&lt;div id=&quot;html_1422a315b1d86a8e9054d35c78f73219&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena&lt;/div&gt;`)[0];
#                 popup_43e80410d1b2ae9528467db3f1ad7911.setContent(html_1422a315b1d86a8e9054d35c78f73219);
#
#
#
#         marker_e9b6bb56ece11d0c50bb9d67aa06eb78.bindPopup(popup_43e80410d1b2ae9528467db3f1ad7911)
#         ;
#
#
#
#
#             var marker_6a1ae7cd2aff17ae051627c56bb074f9 = L.marker(
#                 [3.43722, -76.5225],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#         var popup_8ea8aa2897dbb564f1f3c5f921e7d401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0db242a1964be5c79fd2a492e6c78f89 = $(`&lt;div id=&quot;html_0db242a1964be5c79fd2a492e6c78f89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cali&lt;/div&gt;`)[0];
#                 popup_8ea8aa2897dbb564f1f3c5f921e7d401.setContent(html_0db242a1964be5c79fd2a492e6c78f89);
#
#
#
#         marker_6a1ae7cd2aff17ae051627c56bb074f9.bindPopup(popup_8ea8aa2897dbb564f1f3c5f921e7d401)
#         ;
#
#
#
#
#             var marker_43c5614922a6101d0334f4e4806e5f6f = L.marker(
#                 [6.25184, -75.56359],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62cb2ffdefd3e82b0);
#
#
#         var popup_3b5f32de7a5c90a0daf97db75df7b60f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6f5a44a20dc8f2ffd0441eef5cad817 = $(`&lt;div id=&quot;html_c6f5a44a20dc8f2ffd0441eef5cad817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_3b5f32de7a5c90a0daf97db75df7b60f.setContent(html_c6f5a44a20dc8f2ffd0441eef5cad817);
#
#
#
#         marker_43c5614922a6101d0334f4e4806e5f6f.bindPopup(popup_3b5f32de7a5c90a0daf97db75df7b60f)
#         ;
#
#
#
#
#             var marker_d7a5648a078e3fd831117d2fa726ac5e = L.marker(
#                 [3.43722, -76.5225],
#                 {
# }
#             ).addTo(map_8dd96b3fed37d6d62

# %% [markdown]
# # Conclusiones del informe:

# %% [markdown]
# ### Introducción
# El presente informe se elabora para auxiliar al cliente sobre la decisión respecto a cual, de entre cuatro tiendas, podría vender y obtener fondos para un nuevo emprendimiento en proyecto.
# Se tuvieron en cuenta diversos aspectos: como las ventas totales por tienda, los tipos y productos vendidos, la calificación otorgada según la experiencia del cliente en cada una de las compras realizadas, entre otros. Al final, también se agregan consideraciones respecto a la variable geográfica y la localización de los lugares de compra/venta de los productos ofrecidos en las tiendas.
# Al final se presentan las conclusiones sobre la conveniencia o no de la venta de una de las tiendas y las alternativas que podrían considerarse.
#
# ### Ingresos totales:
# En general, los ingresos totales de las tiendas son muy similares para las tiendas 1, 2 y 3, como se puede ver en la gráfica correspondiente a este punto, y realmente no hay diferencias notables, siendo la Tienda 1 la que registra mayor volumen de ingresos. Aunque si se puede considerar importante la diferencia con respecto a la Tienda 4. Sin embargo, debe observarse que, en el caso de la tienda 4, hay un registro menos en relación al resto de las tiendas, lo que podría influir, aunque posiblemente muy poco -al tratarse de un solo registro-, en el volumen final de ventas.
# De todos modos, considerando una leve compensación en el monto final de ventas de la tienda 4, deja a esta última como la tienda con menor registro en el volumen de ingresos.
#
# ### Categorías de productos más y menos vendidos:
# De los datos de la tabla y como se puede observar claramente en la gráfica, de las ocho categorías consideradas, las más vendidas son muebles, electrónicos, juguetes y electrodomésticos (en ese orden), y presentan un comportamiento similar en todas las tiendas, con excepción de la tienda 4, cuya cuarta categoría en orden de ventas sería deportes y diversión y luego electrodomésticos.
# Las categorías, muebles, juguetes y electrónicos, representan más del 50% de las ventas (en cantidad de productos y volumen de facturación), como se puede ver en la gráfica de torta.
# Artículos para el hogar, libros e instrumentos de música están entre las categorías menos requeridas en general.
#
# ### Calificaciones de las tiendas:
# Del calculo de la calificación promedio por tienda, resulta que la mejor calificada es la Tienda 3, mientras que la Tienda 1 es al peor calificada, aunque las calificaciones entre las tiendas son muy similares, y casi no hay diferencias entre las mismas.
# De la gráfica de las calificaciones por tienda, se obtiene que la tienda 3 es la tienda con mayor cantidad de calificaciones de 5 puntos, mientras que la tienda 1 es la que acumula la mayor cantidad de calificaciones de 1 punto.
# ### Productos: más y menos vendidos
# Se tuvieron en cuenta los diez productos más y menos vendidos por tienda. Aunque en general, como se vio más arriba, hay una coincidencia respecto a las categorías de los productos, no es tan simple realizar un análisis con los productos considerados de manera particular. Hay productos que aparecen entre los más vendidos en una tienda, pero entre los menos vendidos en otra.
#
# ### El coste de envío promedio para cada tienda
# De los datos analizados y la gráfica resultante, se obtiene que el costo promedio de envío más alto lo presenta la tienda 1 (alrededor de 26.000), mientras que la tienda 4 posee el costo de envío promedio más bajo (por encima de los 23.000). Esto último, posiblemente sea uno de los aspectos más positivos que presenta la tienda 1.
# Nota a tener en cuenta: no está claro si los costos de envío los cubre la tienda o el cliente. Además, no es posible indagar más profundamente respecto de porque la tienda 1 presenta costos inferiores de envío, si se tarta de un tema geográfico, una mejor logística o las empresas de encomiendas que emplean para sus envíos.
#
# ### Extra: sobre la variable geográfica
# Todas las tiendas realizan envíos a las mismas ciudades (ver mapa y tabla), destacándose con mayor volumen de ventas, en primer lugar, la ciudad de Bogotá y luego Medellín, Calí y Pereira, en ese orden, y si se observan los diagramas de dispersión para cada tienda en relación al lugar de compra y la cantidad de ventas, se observa muy poca variación entre las mismas.
# Se desconoce cuál es la localización de cada una de las tiendas, lo que podría aportar a un análisis más fino.
#
# ### Conclusión:
# En definitiva, teniendo en cuenta los puntos anteriores, se puede concluir que no hay una gran diferencia entre las tiendas respecto a las variables consideradas, con excepción tal vez de los ingresos.
# Si la decisión de venta de una de las tiendas se basa únicamente en la facturación de la tienda, entonces la tienda 4, al presentar un menor volumen de facturación, es la que debería ser seleccionada para su venta. Pero, si se toman en cuenta las otras variables, entonces las tiendas 2 y 3 también deberían ser consideradas. Esto es, la recomendación al Sr. Juan es que venda cualquiera de las tiendas, con excepción de la tienda 1.
# En el caso de la tienda 1, debería considerarse un plan para la mejora de la atención al público, ya que es la que más notas negativas presenta y mejorar la logística de los envíos (tal vez aplicando el manejo de envíos de la tienda 4).
